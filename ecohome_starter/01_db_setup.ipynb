# %% [markdown]
# # EcoHome Energy Advisor - Database Setup
#
# In this notebook, you'll set up the database for the EcoHome Energy Advisor. The database will store:
# - Energy usage data (consumption, device types, costs)
# - Solar generation data (production, weather conditions)
#
# ## Learning Objectives
# - Create SQLite database with proper schema
# - Populate database with sample data
# - Query data for analysis
# - Understand database design for energy management

# %% [markdown]
# ## 1. Import Required Libraries

# %%
pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (1.4.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (0.9.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (2.14.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain_community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.15.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (4.14.0)
# Requirement already satisfied: distro>=1.7.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: certifi in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.7.0)
# Requirement already satisfied: greenlet>=1 in c:\Users\jonahs\AppData\Local\anaconda3\envs\rag\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain_community) (3.5.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the necessary libraries
from datetime import datetime, timedelta
import random

from models.energy import DatabaseManager

# %% [markdown]
# ## 2. Initialize Database Manager

# %%
# Create a DatabaseManager instance
# Initialize it with the path "data/energy_data.db"
db_manager = DatabaseManager("data/energy_data.db")

# %% [markdown]
# ## 3. Create Database Tables

# %%
# Create the database tables
# Use the create_tables() method from your DatabaseManager
db_manager.create_tables()
# Out:
# Database tables created at data/energy_data.db

# %% [markdown]
# ## 4. Generate Sample Energy Usage Data

# %%
# Generate sample energy usage data for the past 30 days
# Include different device types: EV, HVAC, appliances
# Use realistic consumption patterns (higher during peak hours)

# Device types and their typical consumption patterns
device_types = {
    'EV': {'base_kwh': 10, 'variation': 5, 'peak_hours': [18, 19, 20, 21]},
    'HVAC': {'base_kwh': 2, 'variation': 1, 'peak_hours': [12, 13, 14, 15, 16, 17]},
    'appliance': {'base_kwh': 1.5, 'variation': 0.5, 'peak_hours': [19, 20, 21, 22]}
}

# Generate data for the past 30 days
start_date = datetime.now() - timedelta(days=30)
records_created = 0

for day in range(30):
    current_date = start_date + timedelta(days=day)
    
    for hour in range(24):
        timestamp = current_date.replace(hour=hour, minute=0, second=0, microsecond=0)
        
        # Generate usage for each device type
        for device_type, config in device_types.items():
            # Base consumption with variation
            base_consumption = config['base_kwh']
            variation = random.uniform(-config['variation'], config['variation'])
            
            # Peak hour multiplier
            peak_multiplier = 1.5 if hour in config['peak_hours'] else 0.8
            
            consumption = max(0, (base_consumption + variation) * peak_multiplier)
            
            # Calculate cost (simplified pricing)
            price_per_kwh = 0.15 if hour in config['peak_hours'] else 0.10
            cost = consumption * price_per_kwh
            
            # Device names
            device_names = {
                'EV': 'Tesla Model 3',
                'HVAC': 'Main AC Unit',
                'appliance': random.choice(['Dishwasher', 'Washing Machine', 'Dryer'])
            }
            
            # Add record to database
            db_manager.add_usage_record(
                timestamp=timestamp,
                consumption_kwh=consumption,
                device_type=device_type,
                device_name=device_names[device_type],
                cost_usd=cost
            )
            records_created += 1

print(f"Created {records_created} energy usage records")
# Out:
# Created 2160 energy usage records

# %% [markdown]
# ## 5. Generate Sample Solar Generation Data

# %%
# Generate sample solar generation data
# Consider weather patterns, time of day, and seasonal variations

# Weather conditions and their impact on solar generation
weather_conditions = {
    'sunny': {'multiplier': 1.0, 'probability': 0.4},
    'partly_cloudy': {'multiplier': 0.6, 'probability': 0.3},
    'cloudy': {'multiplier': 0.3, 'probability': 0.2},
    'rainy': {'multiplier': 0.1, 'probability': 0.1}
}

# Generate solar generation data for the same period
start_date = datetime.now() - timedelta(days=30)
generation_records = 0

for day in range(30):
    current_date = start_date + timedelta(days=day)
    
    # Select weather condition for the day
    weather_choice = random.choices(
        list(weather_conditions.keys()),
        weights=[weather_conditions[w]['probability'] for w in weather_conditions.keys()]
    )[0]
    weather_multiplier = weather_conditions[weather_choice]['multiplier']
    
    for hour in range(24):
        timestamp = current_date.replace(hour=hour, minute=0, second=0, microsecond=0)
        
        # Solar generation only during daylight hours (6 AM to 6 PM)
        if 6 <= hour <= 18:
            # Base generation curve (peak at noon)
            hour_factor = 1 - abs(hour - 12) / 6  # Peak at hour 12
            base_generation = 5.0 * hour_factor  # Max 5 kWh at peak
            
            # Apply weather multiplier
            generation = base_generation * weather_multiplier
            
            # Add some random variation
            generation *= random.uniform(0.8, 1.2)
            generation = max(0, generation)
            
            # Calculate temperature (affects solar efficiency)
            base_temp = 20 + random.uniform(-5, 5)
            temp_factor = 1.0 if 15 <= base_temp <= 35 else 0.9
            
            # Solar irradiance calculation
            irradiance = 800 * hour_factor * weather_multiplier if generation > 0 else 0
            
            # Add record to database
            db_manager.add_generation_record(
                timestamp=timestamp,
                generation_kwh=generation,
                weather_condition=weather_choice,
                temperature_c=base_temp * temp_factor,
                solar_irradiance=irradiance
            )
            generation_records += 1

print(f"Created {generation_records} solar generation records")
# Out:
# Created 390 solar generation records

# %% [markdown]
# ## 6. Query and Analyze Data

# %%
# Query the data to verify it was inserted correctly
# Show total consumption by device type
# Show daily solar generation patterns
# Calculate some basic statistics

# Get recent data for analysis
recent_usage = db_manager.get_recent_usage(24)  # Last 24 hours
recent_generation = db_manager.get_recent_generation(24)

print("=== Energy Usage Analysis ===")
print(f"Total records in last 24 hours: {len(recent_usage)}")

# Group by device type
device_consumption = {}
for record in recent_usage:
    device = record.device_type or 'unknown'
    if device not in device_consumption:
        device_consumption[device] = {'kwh': 0, 'cost': 0, 'records': 0}
    device_consumption[device]['kwh'] += record.consumption_kwh
    device_consumption[device]['cost'] += record.cost_usd or 0
    device_consumption[device]['records'] += 1

print("\nConsumption by device type:")
for device, data in device_consumption.items():
    print(f"  {device}: {data['kwh']:.2f} kWh, ${data['cost']:.2f}, {data['records']} records")

print(f"\n=== Solar Generation Analysis ===")
print(f"Total generation records in last 24 hours: {len(recent_generation)}")

total_generation = sum(r.generation_kwh for r in recent_generation)
print(f"Total generation: {total_generation:.2f} kWh")

# Weather breakdown
weather_breakdown = {}
for record in recent_generation:
    weather = record.weather_condition or 'unknown'
    if weather not in weather_breakdown:
        weather_breakdown[weather] = {'kwh': 0, 'records': 0}
    weather_breakdown[weather]['kwh'] += record.generation_kwh
    weather_breakdown[weather]['records'] += 1

print("\nGeneration by weather condition:")
for weather, data in weather_breakdown.items():
    print(f"  {weather}: {data['kwh']:.2f} kWh, {data['records']} records")
# Out:
# === Energy Usage Analysis ===
# Total records in last 24 hours: 84
#
# Consumption by device type:
#   EV: 321.12 kWh, $43.13, 28 records
#   HVAC: 43.27 kWh, $4.33, 28 records
#   appliance: 55.53 kWh, $7.86, 28 records
#
# === Solar Generation Analysis ===
# Total generation records in last 24 hours: 0
# Total generation: 0.00 kWh
#
# Generation by weather condition:

# %% [markdown]
# ## 7. Test Database Tools

# %%
# Test the database query functions from tools.py
# Import and test: query_energy_usage, query_solar_generation, get_recent_energy_summary

from tools import query_energy_usage, query_solar_generation, get_recent_energy_summary

# Test querying data for the last 7 days
end_date = datetime.now().strftime("%Y-%m-%d")
start_date = (datetime.now() - timedelta(days=7)).strftime("%Y-%m-%d")

print("=== Testing Database Tools ===")
print(f"Querying data from {start_date} to {end_date}")

# Test energy usage query
usage_data = query_energy_usage.invoke(
    input={
        "start_date": start_date, 
        "end_date": end_date,
    }
)
print(f"\nEnergy Usage Query Results:")
print(f"  Total records: {usage_data['total_records']}")
print(f"  Total consumption: {usage_data['total_consumption_kwh']} kWh")
print(f"  Total cost: ${usage_data['total_cost_usd']}")

# Test solar generation query
generation_data = query_solar_generation.invoke(
    input={
        "start_date": start_date, 
        "end_date": end_date,
    }
)
print(f"\nSolar Generation Query Results:")
print(f"  Total records: {generation_data['total_records']}")
print(f"  Total generation: {generation_data['total_generation_kwh']} kWh")
print(f"  Average daily: {generation_data['average_daily_generation']} kWh")

# Test recent energy summary
summary = get_recent_energy_summary.invoke(
    input={
        "hours": 24
    }
)
print(f"\nRecent Energy Summary:")
print(f"  Usage: {summary['usage']['total_consumption_kwh']} kWh, ${summary['usage']['total_cost_usd']}")
print(f"  Generation: {summary['generation']['total_generation_kwh']} kWh")
print(f"  Weather: {summary['generation']['average_weather']}")
# Out:
# === Testing Database Tools ===
# Querying data from 2026-06-21 to 2026-06-28
#
# Energy Usage Query Results:
#   Total records: 3528
#   Total consumption: 14698.71 kWh
#   Total cost: $1685.11
#
# Solar Generation Query Results:
#   Total records: 637
#   Total generation: 821.9 kWh
#   Average daily: 102.74 kWh
#
# Recent Energy Summary:
#   Usage: 419.93 kWh, $55.32
#   Generation: 0 kWh
#   Weather: unknown
